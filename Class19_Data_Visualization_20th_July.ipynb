# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline             #Render plots from Matplotlib directly inside the notebook, rather than in a separate window.
from numpy.random import randn
# Out:
# UsageError: unrecognized arguments: #Render plots from Matplotlib directly inside the notebook, rather than in a separate window.

# %%
df=pd.DataFrame(randn(10,4),columns=['a','b','c','d'])
df

# %% [markdown]
# # Seaborn library

# %%
# In-built datasets within seaborn for practice. Let's list them
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
iris=sns.load_dataset('iris')    # iris is a dataset of plant
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
# Creating a histogram of sepal_length
iris.sepal_length.plot(kind='hist')
plt.show()

# %%
# Creating histogram with more bins (bars) by specifying the bins value
iris.sepal_length.plot(kind='hist',bins=30)
plt.show()

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# Dropping species column
df=iris.drop(['species'],axis=1)
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
# Creating histogram for entire dataset having 4 columns. It will generate 4 plots for each of the columns
df.hist(color='g',figsize=(20,10),bins=30)   # Figsize (20,10) means, 20 inches for rows and 10 inches for columns
plt.show()

# %% [markdown]
# ## Difference between Matplotlib and Seabord
#
# Both are popular python libraries used for data visualization
#
# ### Matplotlib
#
# 1. Basic Library: Matplotlib is the foundation of all python libraries. It gives full control overy every part of a figure.
# 2. Low-level: You have to write more code to customize plots. Everything must be built step-by-step.
# 3. Versatile: You can create many types of plots - line, bar, scatter, histogram etc... but sometimes styling is manual.
# 4. More Customization: You can fine tune every part of the chart - fonts, color, ticks, levels, grids etc...
#
# ### Seaborn
#
# 1. Built on Matplotlib: Seaborn is based on Matplotlib but gives prettier and simpler charts with less code.
# 2. High-level API: It is easier to make complex plots like boxplots, violin plots and heatmaps.
# 3. Beautiful by default: Comes with better styling, color themes, and design out of the box.
# 4. Works well with DataFrames: Seaborn directly works with pandas dataframes, making it great for statistical plot.
#
# #### Conclusion
#
# - Use **Matplotlib** when you need full control and customization
# - User **Seaborn** when you want quick, beautiful and statistical visualization

# %%
emp={'Age_Years':[1,23,22,25,20,23,24,27,25,24,103,21],
     'Salary_Thousand':[15,22,24,25,30,23,34,43,19,20,52,21]}
df=pd.DataFrame(emp)
df
# Out:
#     Age_Years  Salary_Thousand
# 0           1               15
# 1          23               22
# 2          22               24
# 3          25               25
# 4          20               30
# 5          23               23
# 6          24               34
# 7          27               43
# 8          25               19
# 9          24               20
# 10        103               52
# 11         21               21

# %% [markdown]
# ### Boxplot
#
# It displays Outliers.

# %%
# Let's try to create a boxplot with the above dataframe
plt.figure(figsize=(4,4))
sns.boxplot(data=df)
plt.yticks(range(5,60,5))  #Range on Y axis
plt.xlabel('Age and Salary')
plt.show()

# %% [markdown]
# Notice 5 lines in both the plots. Let's concentrate on Orange plot starting from below there are total 5 horizontal lines including the surface of orange box.
#
# - First line: **minimum value**
# - Second line (below surface of orange box): 25%
# - Third line (line within the box): 50%
# - Fourth line (upper surface of orance box): 75%
# - Fifth line: **maximum value**
#
# **NOTE**: Any data lies between minimum and maximum value, it is a normal data. Anything outside this boundary are known as **outliers**.
#
# ##### Seaborn keeps updating it's code, if any code doesn't work please refer to the official documentation https://seaborn.pydata.org/

# %%
# Another way to create the boxplot

df.plot(kind='box',figsize=(8,5),color='r',yticks=range(0,55,5))
plt.show()

# %% [markdown]
# ### How it finds the Outliers?
#
# Let's understand how it works in the backend to find the outliers. It uses **Inter Quantile Range (IQR)** for calculating.

# %%
# Let's take a list

sal=[15,22,24,25,30,23,34,43,19,20,52,21,2]
sal.sort()
sal
# Out:
# [2, 15, 19, 20, 21, 22, 23, 24, 25, 30, 34, 43, 52]

# %%
# Convert sal into series
import pandas as pd
ser=pd.Series(sal)
ser
# Out:
# 0      2
# 1     15
# 2     19
# 3     20
# 4     21
# 5     22
# 6     23
# 7     24
# 8     25
# 9     30
# 10    34
# 11    43
# 12    52
# dtype: int64

# %%
# While calculating IQR, we need below 3 values

# 1st quantile
q1=ser.quantile(0.25)
print("Q1",q1)

# 3rd quantile
q3=ser.quantile(0.75)
print("Q3",q3)

# Find the IQR for outliers
iqr=q3-q1
print("IQR",iqr)
# Out:
# Q1 20.0
# Q3 30.0
# IQR 10.0

# %% [markdown]
# Given the dataset:
# [15, 19, 20, 21, 22, 23, 24, 25, 30, 34, 43, 52]
#
# n=Total elements in the dataset = 12
#
# ### Percentile Calculations
#
# • **25th percentile:**
#
# (25/100) (n + 1) = 0.25 (12 + 1) = 3.25
# The data at the 3.25th position is approximately 20.5 (interpolated between the 3rd and 4th elements). 3.25 is the index value.
#
# • **50th Percentile (Median):**
#
# (50/100) * (n + 1) = 0.5 * (12 + 1) = 6.5
# The data at the 6.5th position is approximately 23.5 (interpolated between the 6th and 7th elements).
#
# • **75th Percentile:**
#
# (75/100) * (n + 1) = 0.75 * (12 + 1) = 9.75
# The data at the 9.75th position is approximately 31.5 (interpolated between the 9th and 10th elements).

# %% [markdown]
# ### Outlier detection formula
#
# higher side --> Q3 + (1.5*IQR)
#
# lower side --> Q1 - (1.5*IQR)

# %%
upperside=q3+(1.5*iqr)
print("1. Anything which is more than:",upperside,"is an outlier.")
lowerside=q1-(1.5*iqr)
print("2. Anything which is lesser than:",lowerside,"is an outlier.")
# Out:
# 1. Anything which is more than: 45.0 is an outlier.
# 2. Anything which is lesser than: 5.0 is an outlier.

# %%
df.plot(kind='box',figsize=(3,3),color='g',yticks=range(0,55,5))
plt.show()

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from pandas.plotting import scatter_matrix

# %% [markdown]
# ## IRIS dataset

# %%
iris=sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df=iris.drop(['species'],axis=1)
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
# Pie Plot

rupees_monthly=[2000,2530,900,1500,1500]
items=['Tution_fee','Mobile_bill','Electric_bill','Rent','Misc']
print('Total:',sum(rupees_monthly))
plt.pie(x=rupees_monthly,labels=items)
plt.show()
# Out:
# Total: 8430

# %%
plt.figure(figsize=(3,3))
plt.pie(x=rupees_monthly,labels=items,explode=[0,0,0,0.1,0],rotatelabels=True,autopct="%1.2f%%")  
# Explode meaning bringing one portion out of pie chart.
# rotatelabels is rotating the labels, follow the label writting
# autopct meaning 1 -> before decimal point; .2 -> two digits after decimal point. Example: 30.01%
plt.show()

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
# relplot()
# scatterplot()
# inlineplot()
tips=sns.load_dataset('tips')
tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
sns.relplot(x='total_bill',y='tip',data=tips)  # Tip gets increased based on the total bill, that's the relation it shows in relplot()
plt.show()

# %%
tips['smoker'].value_counts()    # .value_counts() is from seaborn library
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
sns.relplot(x='total_bill',y='tip',data=tips,hue='smoker',style='time')   #hue is a parameter (seaborn-relplot) to distribute the data based on style
plt.show()

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from pandas.plotting import scatter_matrix
tips=sns.load_dataset('tips')
sns.relplot(x='total_bill',y='tip',data=tips,size='size')    # small cicrle= 1 person, little more bigger circle=2 persons and so on...
plt.show()

# %%
sns.scatterplot(x='total_bill',y='tip',data=tips,size='size')
plt.show()

# %%
sns.lineplot(x='total_bill',y='tip',data=tips,size='size')
plt.show()
